# %% [markdown]
# # **PART A**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from sklearn.preprocessing import MinMaxScaler
import torch

# %%
# load dataset
data = pd.read_csv('https://raw.githubusercontent.com/aaubs/ds-master/main/data/Swedish_Auto_Insurance_dataset.csv')

# %%
# Using sklearn
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)
data_s = pd.DataFrame(data_scaled, columns=data.columns)

# %%
# Hyperparameters
epochs = 1
learning_rate = 0.00037

# %%
# Initial parameter
w = 3.8

# %%
# 1. Creating a Neural Network
# 1.1 Structure (Architecture) of NN
def nn(x, w):
    """Compute prediction: y_hat = x * w"""
    return x * w

# %%
# 1.2 Loss Function
def loss(y_hat, t):
    """Calculate the Mean Squared Error"""
    return ((t - y_hat)**2)

# %%
# 1.3 Gradient of the loss w.r.t weight
def gradient(w, x, t):
    """Compute gradient: dL/dw = 2x(y_hat - t)"""
    y_hat = x * w
    return 2 * x * (y_hat - t)

# %%
def delta_w(w_i, x, t, learning_rate):
    """Compute the weight update Δw"""
    return learning_rate * gradient(w_i, x, t)

# %%
# Store weight history
w_his = []
w_his.append(w)

# %%
# Training loop (SGD)
for epoch in range(epochs):
    total_loss = 0

    for i in range(len(data_s['X'])):
        x_i, t_i = data_s['X'][i], data_s['Y'][i]

        # 2. Forward Pass
        y_hat = nn(x_i, w)

        # 3. Loss Evaluation
        loss_val = loss(y_hat, t_i)

        # 4. Gradient Calculation
        grad_value = gradient(w, x_i, t_i)
        dw = delta_w(w, x_i, t_i, learning_rate)

        # 5. Backpropagation / Weight Update (SGD)
        w = w - dw
        w_his.append(w)

        total_loss += loss_val

        print(
            f"Epoch {epoch+1}, Sample {i+1}: "
            f"Gradient={grad_value:.4f}, Δw={dw:.4f}, "
            f"w={w:.4f}, Loss={loss_val:.4f}"
        )

    avg_loss = total_loss / len(data_s['X'])
    print(f"Epoch {epoch+1}: Average Loss = {avg_loss:.4f}\n")
# Out:
# Epoch 1, Sample 1: Gradient=4.1458, Δw=0.0015, w=3.7985, Loss=5.6645
# Epoch 1, Sample 2: Gradient=0.1448, Δw=0.0001, w=3.7984, Loss=0.2233
# Epoch 1, Sample 3: Gradient=0.0757, Δw=0.0000, w=3.7984, Loss=0.1303
# Epoch 1, Sample 4: Gradient=5.5968, Δw=0.0021, w=3.7963, Loss=7.8310
# Epoch 1, Sample 5: Gradient=0.6076, Δw=0.0002, w=3.7961, Loss=0.8870
# Epoch 1, Sample 6: Gradient=1.2321, Δw=0.0005, w=3.7956, Loss=1.7961
# Epoch 1, Sample 7: Gradient=0.2112, Δw=0.0001, w=3.7956, Loss=0.3241
# Epoch 1, Sample 8: Gradient=0.0553, Δw=0.0000, w=3.7955, Loss=0.0600
# Epoch 1, Sample 9: Gradient=0.6318, Δw=0.0002, w=3.7953, Loss=0.7578
# Epoch 1, Sample 10: Gradient=0.0244, Δw=0.0000, w=3.7953, Loss=0.0229
# Epoch 1, Sample 11: Gradient=0.0083, Δw=0.0000, w=3.7953, Loss=0.0107
# Epoch 1, Sample 12: Gradient=0.6825, Δw=0.0003, w=3.7950, Loss=0.7771
# Epoch 1, Sample 13: Gradient=0.0499, Δw=0.0000, w=3.7950, Loss=0.0790
# Epoch 1, Sample 14: Gradient=0.2263, Δw=0.0001, w=3.7949, Loss=0.3722
# Epoch 1, Sample 15: Gradient=0.0111, Δw=0.0000, w=3.7949, Loss=0.0097
# Epoch 1, Sample 16: Gradient=0.0015, Δw=0.0000, w=3.7949, Loss=0.0021
# Epoch 1, Sample 17: Gradient=0.1606, Δw=0.0001, w=3.7949, Loss=0.1722
# Epoch 1, Sample 18: Gradient=0.0061, Δw=0.0000, w=3.7949, Loss=0.0040
# Epoch 1, Sample 19: Gradient=0.0039, Δw=0.0000, w=3.7949, Loss=0.0066
# Epoch 1, Sample 20: Gradient=0.1618, Δw=0.0001, w=3.7948, Loss=0.1903
# Epoch 1, Sample 21: Gradient=0.0144, Δw=0.0000, w=3.7948, Loss=0.0221
# Epoch 1, Sample 22: Gradient=0.0232, Δw=0.0000, w=3.7948, Loss=0.0256
# Epoch 1, Sample 23: Gradient=0.0221, Δw=0.0000, w=3.7948, Loss=0.0231
# Epoch 1, Sample 24: Gradient=0.0029, Δw=0.0000, w=3.7948, Loss=0.0037
# Epoch 1, Sample 25: Gradient=0.3000, Δw=0.0001, w=3.7947, Loss=0.4114
# Epoch 1, Sample 26: Gradient=0.0035, Δw=0.0000, w=3.7947, Loss=0.0009
# Epoch 1, Sample 27: Gradient=0.0061, Δw=0.0000, w=3.7947, Loss=0.0089
# Epoch 1, Sample 28: Gradient=0.1225, Δw=0.0000, w=3.7946, Loss=0.1442
# Epoch 1, Sample 29: Gradient=0.0167, Δw=0.0000, w=3.7946, Loss=0.0219
# Epoch 1, Sample 30: Gradient=0.0021, Δw=0.0000, w=3.7946, Loss=0.0010
# Epoch 1, Sample 31: Gradient=0.0000, Δw=0.0000, w=3.7946, Loss=0.0000
# Epoch 1, Sample 32: Gradient=0.2424, Δw=0.0001, w=3.7945, Loss=0.3614
# Epoch 1, Sample 33: Gradient=0.0144, Δw=0.0000, w=3.7945, Loss=0.0222
# Epoch 1, Sample 34: Gradient=0.0046, Δw=0.0000, w=3.7945, Loss=0.0033
# Epoch 1, Sample 35: Gradient=0.1032, Δw=0.0000, w=3.7945, Loss=0.0845
# Epoch 1, Sample 36: Gradient=0.0357, Δw=0.0000, w=3.7945, Loss=0.0405
# Epoch 1, Sample 37: Gradient=1.3294, Δw=0.0005, w=3.7940, Loss=1.8258
# Epoch 1, Sample 38: Gradient=0.0444, Δw=0.0000, w=3.7940, Loss=0.0527
# Epoch 1, Sample 39: Gradient=0.0060, Δw=0.0000, w=3.7940, Loss=0.0086
# Epoch 1, Sample 40: Gradient=0.0899, Δw=0.0000, w=3.7939, Loss=0.1214
# Epoch 1, Sample 41: Gradient=0.0388, Δw=0.0000, w=3.7939, Loss=0.0342
# Epoch 1, Sample 42: Gradient=1.3126, Δw=0.0005, w=3.7934, Loss=1.8397
# Epoch 1, Sample 43: Gradient=0.5455, Δw=0.0002, w=3.7932, Loss=0.6804
# Epoch 1, Sample 44: Gradient=0.4595, Δw=0.0002, w=3.7931, Loss=0.5928
# Epoch 1, Sample 45: Gradient=1.1504, Δw=0.0004, w=3.7926, Loss=1.6817
# Epoch 1, Sample 46: Gradient=0.7143, Δw=0.0003, w=3.7924, Loss=1.1668
# Epoch 1, Sample 47: Gradient=0.0507, Δw=0.0000, w=3.7923, Loss=0.0818
# Epoch 1, Sample 48: Gradient=0.2641, Δw=0.0001, w=3.7922, Loss=0.3678
# Epoch 1, Sample 49: Gradient=0.0083, Δw=0.0000, w=3.7922, Loss=0.0041
# Epoch 1, Sample 50: Gradient=-0.0001, Δw=-0.0000, w=3.7922, Loss=0.0000
# Epoch 1, Sample 51: Gradient=0.0503, Δw=0.0000, w=3.7922, Loss=0.0336
# Epoch 1, Sample 52: Gradient=0.0372, Δw=0.0000, w=3.7922, Loss=0.0314
# Epoch 1, Sample 53: Gradient=0.0675, Δw=0.0000, w=3.7922, Loss=0.1037
# Epoch 1, Sample 54: Gradient=0.0926, Δw=0.0000, w=3.7922, Loss=0.1465
# Epoch 1, Sample 55: Gradient=0.0146, Δw=0.0000, w=3.7921, Loss=0.0128
# Epoch 1, Sample 56: Gradient=0.2671, Δw=0.0001, w=3.7920, Loss=0.3262
# Epoch 1, Sample 57: Gradient=0.2210, Δw=0.0001, w=3.7920, Loss=0.2086
# Epoch 1, Sample 58: Gradient=0.1577, Δw=0.0001, w=3.7919, Loss=0.1659
# Epoch 1, Sample 59: Gradient=0.0099, Δw=0.0000, w=3.7919, Loss=0.0047
# Epoch 1, Sample 60: Gradient=0.2255, Δw=0.0001, w=3.7918, Loss=0.2035
# Epoch 1, Sample 61: Gradient=0.0456, Δw=0.0000, w=3.7918, Loss=0.0408
# Epoch 1, Sample 62: Gradient=0.8902, Δw=0.0003, w=3.7915, Loss=1.0844
# Epoch 1, Sample 63: Gradient=0.1471, Δw=0.0001, w=3.7914, Loss=0.1231
# Epoch 1: Average Loss = 0.4990

# %% [markdown]
# # **PART B**

# %% [markdown]
# Sentence 1: "the bat flew"
# Sentence 2: "the bat swung"

# %%
# Sentence 1: animal meaning
embeddings_bat_animal = {
    "the":  np.array([0.1, 0.1]),
    "bat":  np.array([0.5, 0.5]),
    "flew": np.array([0.1, 0.9])
}

# Sentence 2: sports meaning
embeddings_bat_sports = {
    "the":   np.array([0.1, 0.1]),
    "bat":   np.array([0.5, 0.5]),
    "swung": np.array([0.9, 0.1])
}

# %%
# Sentence 1 (animal meaning)
sentence_1 = ["the", "bat", "flew"]

# Initialize matrices for Q, K, V
Q_1 = np.array([embeddings_bat_animal[word] for word in sentence_1])
K_1 = np.array([embeddings_bat_animal[word] for word in sentence_1])
V_1 = np.array([embeddings_bat_animal[word] for word in sentence_1])

# Step 1: Similarity - Calculate dot products for Q and K (attention scores)
attention_scores_1 = Q_1.dot(K_1.T)

# Step 2: Weights - Apply softmax to attention scores
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

attention_weights_1 = np.apply_along_axis(softmax, 1, attention_scores_1)

# Step 3: Contextualized vectors
attention_output_1 = attention_weights_1.dot(V_1)

# %%
# Sentence 2 (sports meaning)
sentence_1 = ["the", "bat", "swung"]

# Initialize matrices for Q, K, V
Q_2 = np.array([embeddings_bat_sports[word] for word in sentence_1])
K_2 = np.array([embeddings_bat_sports[word] for word in sentence_1])
V_2 = np.array([embeddings_bat_sports[word] for word in sentence_1])

# Step 1: Similarity - Calculate dot products for Q and K (attention scores)
attention_scores_2 = Q_1.dot(K_1.T)

# Step 2: Weights - Apply softmax to attention scores
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

attention_weights_2 = np.apply_along_axis(softmax, 1, attention_scores_1)

# Step 3: Contextualized vectors
attention_output_2 = attention_weights_1.dot(V_1)

# %%
Q_1
# Out:
# array([[0.1, 0.1],
#        [0.5, 0.5],
#        [0.1, 0.9]])

# %%
Q_2
# Out:
# array([[0.1, 0.1],
#        [0.5, 0.5],
#        [0.9, 0.1]])

# %%
attention_scores_1
# Out:
# array([[0.02, 0.1 , 0.1 ],
#        [0.1 , 0.5 , 0.5 ],
#        [0.1 , 0.5 , 0.82]])

# %%
attention_scores_2
# Out:
# array([[0.02, 0.1 , 0.1 ],
#        [0.1 , 0.5 , 0.5 ],
#        [0.1 , 0.5 , 0.82]])

# %%
attention_weights_1
# Out:
# array([[0.3157987 , 0.34210065, 0.34210065],
#        [0.25102611, 0.37448695, 0.37448695],
#        [0.21996112, 0.32814344, 0.45189544]])

# %%
attention_weights_2
# Out:
# array([[0.3157987 , 0.34210065, 0.34210065],
#        [0.25102611, 0.37448695, 0.37448695],
#        [0.21996112, 0.32814344, 0.45189544]])

# %%
attention_output_1
# Out:
# array([[0.23684026, 0.51052078],
#        [0.24979478, 0.54938434],
#        [0.23125737, 0.59277373]])

# %%
attention_output_2
# Out:
# array([[0.51052078, 0.23684026],
#        [0.54938434, 0.24979478],
#        [0.59277373, 0.23125737]])

# %%
bat_1 = attention_output_1[1]   # bat in animal context
bat_2 = attention_output_2[1]   # bat in sports context

# %%
distance = np.linalg.norm(bat_1 - bat_2)
distance
# Out:
# np.float64(0.4236836148453855)
